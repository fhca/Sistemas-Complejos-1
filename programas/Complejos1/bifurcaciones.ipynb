# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#from matplotlib import cm

def logistic(c, x):
    return c * x * (1 - x)

def seno(c, x):
    return c * np.sin(x)

función = logistic
fig = plt.figure()
ax = fig.add_subplot(111)

N=2000  # N x N square window, (resolution)
C = np.linspace(-4, 4, N)
Y = np.array([-0.5] * N)
Y[0::2]*=-1
for _ in range(500):
    Y = función(C, Y)  # wasted initial values
for _ in range(N):
    Y = función(C, Y)
    ax.plot(C, Y, 'k,')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: overflow encountered in multiply
